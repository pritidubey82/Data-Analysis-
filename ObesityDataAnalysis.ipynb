# %%
##Name:Priti Dubey
##Assigment - 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
##opening the file
df=pd.read_csv("ObesityDataSet.csv")
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
Obesity is a major global health challenge that has been steadily increasing in prevalence over the past few decades. It is associated with numerous health complications, including cardiovascular diseases, diabetes, musculoskeletal disorders, and certain types of cancer. Understanding the factors that contribute to obesity and identifying effective intervention strategies are crucial for public health initiatives. To facilitate research and data-driven decision-making, comprehensive datasets on obesity are essential.
Dataset Overview
This obesity dataset contains detailed information about individuals, capturing a wide range of variables that can influence body weight and health outcomes. The dataset includes Gender, age,height ,weight,family history,favc,fcvc,ncp,caes,smoke,ch20,scc,faf,tue,calc. By analyzing this data, researchers can identify patterns, correlations, and potential causal relationships that contribute to obesity

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# NObeyesdad                        0
# dtype: int64

# %%
we have conducted a detailed study to identify the age group that exhibits the highest prevalence of smoking. Understanding these patterns is crucial for public health planning and targeted intervention strategiesThis report outlines our methodology, key findings, and recommendations based on the analysis of smoking data segmented by age groups.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
age_smoke_counts = df.groupby(['Age', 'SMOKE']).size().reset_index

# %%
df.describe()
# Out:
#                Age       Height       Weight         FCVC          NCP  \
# count  2111.000000  2111.000000  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058     2.419043     2.685628
# std       6.345968     0.093305    26.191172     0.533927     0.778039
# min      14.000000     1.450000    39.000000     1.000000     1.000000
# 25%      19.947192     1.630000    65.473343     2.000000     2.658738
# 50%      22.777890     1.700499    83.000000     2.385502     3.000000
# 75%      26.000000     1.768464   107.430682     3.000000     3.000000
# max      61.000000     1.980000   173.000000     3.000000     4.000000
#
#               CH2O          FAF          TUE
# count  2111.000000  2111.000000  2111.000000
# mean      2.008011     1.010298     0.657866
# std       0.612953     0.850592     0.608927
# min       1.000000     0.000000     0.000000
# 25%       1.584812     0.124505     0.000000
# 50%       2.000000     1.000000     0.625350
# ...

# %%
age_smoke_counts = df.groupby(['Age', 'SMOKE']).size().reset_index(name='count')
smokers_data = age_smoke_counts[age_smoke_counts['SMOKE'] == 'yes']
##ploted a bar graph to show number of smoker in particular age group
plt.figure(figsize=(10, 6))
plt.bar(smokers_data['Age'], smokers_data['count'], color='skyblue')
plt.xlabel('Age')
plt.ylabel('Number of Smokers')
plt.title('Number of Smokers by Age Group')
plt.xticks(rotation=45)
plt.show()

# %%
age_smoke_counts = df.groupby(['Age', 'SMOKE']).size().reset_index(name='count')
smokers_data = age_smoke_counts[age_smoke_counts['SMOKE'] == 'yes']
##Same show in Pie chart for better UNderstanding
age_labels = smokers_data['Age'].unique()
smokers_by_age = smokers_data.groupby('Age')['count'].sum()

plt.pie(smokers_by_age, labels=age_labels, autopct='%1.1f%%')
plt.title("Smokers by Age Groups")
plt.show()

# %%
## Above are the representation through bar and pie chart which age group smoke moree

# %%
df = df.dropna(subset=['Gender', 'SMOKE'])##count of Number of smoker in males anf females
smokers = df[df['SMOKE'] == 'yes']
gender_counts = smokers['Gender'].value_counts()

print(gender_counts)
# Out:
# Gender
# Male      29
# Female    15
# Name: count, dtype: int64

# %%
## Above the the count of How many Male and Female smoker smoke

# %%
gender_counts.plot(kind='bar', color=['blue', 'pink'])
plt.title('Number of Male and Female Smokers')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
#graphically the counto of smokers in male and female

# %%
## Count of Male Smoker is more

# %%
mean_weights_by_gender = df.groupby('Gender')['Weight'].mean()

print("Mean weights by gender:")
print(mean_weights_by_gender)
# Out:
# Mean weights by gender:
# Gender
# Female    82.302364
# Male      90.769478
# Name: Weight, dtype: float64

# %%
if mean_weights_by_gender['Male'] > mean_weights_by_gender['Female']:
    print("Males have a higher mean weight.")
elif mean_weights_by_gender['Male'] < mean_weights_by_gender['Female']:
    print("Females have a higher mean weight.")
else:
    print("Males and females have the same mean weight.")
##here i have used some additonal KNnowledge of ppython to compare the weight
# Out:
# Males have a higher mean weight.

# %%
df_cleaned = df.dropna(subset=['Weight', 'Gender'])
mean_weights_by_gender = df_cleaned.groupby('Gender')['Weight'].mean()
plt.figure(figsize=(10, 6))
mean_weights_by_gender.plot(kind='bar', color=['blue', 'pink'])
plt.title('Mean Weight by Gender')
plt.xlabel('Gender')
plt.ylabel('Mean Weight')
plt.xticks(rotation=0)
plt.show()
##graphical represntation

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.hist(df['Age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(df['Height'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Height')
plt.xlabel('Height')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(df['Weight'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Weight')
plt.xlabel('Weight')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.hist(df['FCVC'], bins=20, color='lightskyblue', edgecolor='black')
plt.title('Distribution of FCVC')
plt.xlabel('FCVC')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()


## here i have used my knownlegde and tried to put the four graph simultaneoulsy for better understading

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
plt.hist(df['FAVC'], bins=20, color='Red', edgecolor='black')
plt.title('Distribution of FAVC')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(df['FCVC'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of FCVC')
plt.xlabel('FCVC')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(df['NCP'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of NCP')
plt.xlabel('NCP')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.hist(df['CAEC'], bins=20, color='Yellow', edgecolor='black')
plt.title('Distribution of CAEC')
plt.xlabel('CAEC')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.subplot(1, 2, 1)
gender_groups = df.groupby('Gender')['Weight'].mean()
plt.bar(gender_groups.index, gender_groups.values, color=['blue', 'pink'])
plt.title('Average Weight by Gender')
plt.xlabel('Gender')
plt.ylabel('Average Weight')
# Out:
# Text(0, 0.5, 'Average Weight')

# %%
plt.subplot(1, 2, 2)
history_groups = df.groupby('family_history_with_overweight')['Weight'].mean()
plt.bar(history_groups.index, history_groups.values, color=['green', 'orange'])
plt.title('Average Weight by Family History with Overweight')
plt.xlabel('Family History with Overweight')
plt.ylabel('Average Weight')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
colors = {'Female': 'red', 'Male': 'blue'}
plt.scatter(df['FAF'], df['Weight'], c=df['Gender'].apply(lambda x: colors[x]), alpha=0.5)
plt.title('Relationship between FAF and Weight by Gender')
plt.xlabel('FAF (Physical Activity Frequency)')
plt.ylabel('Weight')
plt.legend(['Female', 'Male'])
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.subplot(1, 2, 1)
smoke_counts = df['SMOKE'].value_counts()
plt.bar(smoke_counts.index, smoke_counts.values, color=['purple', 'brown'])
plt.title('Count of Smokers')
plt.xlabel('Smoke Status')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
gender_mtrans_counts = df.groupby(['Gender', 'MTRANS']).size()
gender_mtrans_counts
# Out:
# Gender  MTRANS
# Female  Automobile               166
#         Motorbike                  2
#         Public_Transportation    854
#         Walking                   21
# Male    Automobile               291
#         Bike                       7
#         Motorbike                  9
#         Public_Transportation    726
#         Walking                   35
# dtype: int64

# %%
gender_mtrans_counts.unstack().plot(kind='bar', figsize=(10,6), color=['red', 'green', 'blue', 'yellow'])
plt.title('Count of Observations by Gender and MTRANS')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='MTRANS')
plt.show()

# %%
age_nobeyesdad_counts = df.groupby('Age')['NObeyesdad'].value_counts().unstack()
age_nobeyesdad_counts
# Out:
# NObeyesdad  Insufficient_Weight  Normal_Weight  Obesity_Type_I  \
# Age
# 14.000000                   NaN            1.0             NaN
# 15.000000                   NaN            NaN             1.0
# 16.000000                   2.0            6.0             NaN
# 16.093234                   NaN            NaN             NaN
# 16.129279                   NaN            NaN             1.0
# ...                         ...            ...             ...
# 55.022494                   NaN            NaN             NaN
# 55.137881                   NaN            NaN             NaN
# 55.246250                   NaN            NaN             NaN
# 56.000000                   NaN            NaN             NaN
# 61.000000                   NaN            1.0             NaN
#
# NObeyesdad  Obesity_Type_II  Obesity_Type_III  Overweight_Level_I  \
# Age
# 14.000000               NaN               NaN                 NaN
# ...

# %%
df.dropna()
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
bins = [0, 20, 30, 40, 50, 60, 70, 80, 90, 100]
labels = ['0-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', '91-100']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
age_obesity_proportion = df[df['NObeyesdad'].str.contains('Obesity')].groupby('AgeGroup', observed=True).size() / df.groupby('AgeGroup', observed=True).size()
plt.figure(figsize=(12, 6))
age_obesity_proportion.plot(kind='bar', color='yellow')
plt.title('Proportion of Obesity by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Proportion of Obesity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
age_bins = [20, 30, 40, 50, 60, 70]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60+']


df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)


obese_counts = df[df['NObeyesdad'] == 'Normal_Weight'].groupby('Age Group').size()

# Plotting the bar graph
plt.figure(figsize=(10, 6))
obese_counts.plot(kind='bar', color='skyblue')
plt.title('Number of Obese Individuals by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Obese Individuals')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Priti\AppData\Local\Temp\ipykernel_20768\3686037922.py:8: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   obese_counts = df[df['NObeyesdad'] == 'Normal_Weight'].groupby('Age Group').size()

# %%
age_bins = [20, 30, 40, 50, 60, 70]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60+']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)
categories = ['Normal_Weight', 'Overweight_Level_I', 'Overweight_Level_II', 'Obesity_Type_III',
              'Insufficient_Weight', 'Obesity_Type_II', 'Obesity_Type_I']
plt.figure(figsize=(14, 10))
for i, category in enumerate(categories):
    obese_counts = df[df['NObeyesdad'] == category].groupby('Age Group', observed=True).size()
    
    plt.subplot(3, 3,i+1) 
    obese_counts.plot(kind='bar', color='red')
    plt.title(f'Age Group Distribution for {category}')
    plt.xlabel('Age Group')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()

plt.show()

# %%
age_bins = [20, 30, 40, 50, 60, 70]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60+']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)
categories = ['Public_Transportation', 'Walking', 'Automobile', 'Motorbike']
plt.figure(figsize=(14, 10))
for i, category in enumerate(categories):
    obese_counts = df[df['MTRANS'] == category].groupby('Age Group', observed=True).size()
    
    plt.subplot(3, 3,i+1) 
    obese_counts.plot(kind='bar', color='yellow')
    plt.title(f'Age Group Distribution for {category}')
    plt.xlabel('Age Group')
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.tight_layout()

plt.show()

# %%
age_bins = [20, 30, 40, 50, 60, 70]
age_labels = ['20-29', '30-39', '40-49', '50-59', '60+']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels)
counts = df.groupby(['Age Group', 'family_history_with_overweight'], observed=True).size().unstack()
counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Distribution of Family History with Overweight by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Family History with Overweight', loc='upper right')
plt.tight_layout()
plt.show()

# %%
Conclusion:The analysis of age groups and obesity reveals notable trends. Obesity prevalence is prominently observed in the age group 41-50, as indicated by the visualization of proportions across age groups. Specifically, individuals categorized as normal weight are predominantly found in the 20-29 age group. Overweight Level 1 individuals are prevalent in both the 20-29 and 30-39 age groups, while Overweight Level 2 spans across all age groups. Obesity Type 3 is predominantly observed in the 20-29 and 30-39 age groups.
In terms of transportation modes, individuals aged 20-29 primarily utilize public transportation, walking, and motorbikes. The use of automobiles is notably higher among those aged 30-39.
Additionally, the analysis of family history with overweight indicates a higher prevalence among individuals aged 20-29.
These findings provide insights into age-related patterns of obesity, transportation preferences, and familial health indicators, contributing valuable information for further research and policy considerations in public health and urban planning.

# %%
counts = df.groupby(['NObeyesdad', 'SMOKE']).size().unstack()

counts.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Smoking Status vs Obesity Category')
plt.xlabel('Obesity Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Smoker', loc='upper right')
plt.tight_layout()
plt.show()

# %%
Conclusion: The analysis of age groups and obesity reveals notable trends. Obesity prevalence is prominently observed in the age group 41-50, as indicated by the visualization of proportions across age groups. Specifically, individuals categorized as normal weight are predominantly found in the 20-29 age group. Overweight Level 1 individuals are prevalent in both the 20-29 and 30-39 age groups, while Overweight Level 2 spans across all age groups. Obesity Type 3 is predominantly observed in the 20-29 and 30-39 age groups.
In terms of transportation modes, individuals aged 20-29 primarily utilize public transportation, walking, and motorbikes. The use of automobiles is notably higher among those aged 30-39.
Additionally, the analysis of family history with overweight indicates a higher prevalence among individuals aged 20-29.
Moreover, the number of smokers is concentrated in the all age group, reflecting a significant proportion of smokers within this demographic.
These findings provide insights into age-related patterns of obesity, transportation preferences, smoking behaviors, and familial health indicators. They contribute valuable information for further research and policy considerations in public health, urban planning, and behavioral interventions.
